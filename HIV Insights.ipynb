# %% [markdown]
# # HIV Project

# %%
import pandas as pd

# %%
df= pd.read_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV-DATASET.xlsx")

# %%
df.head()
# Out:
#    area_level area_level_label area_id     area_name   sex age_group  \
# 0           0          Country     ZAF  South Africa  both  Y015_049
# 1           0          Country     ZAF  South Africa  both  Y015_064
# 2           0          Country     ZAF  South Africa  both  Y015_999
# 3           0          Country     ZAF  South Africa  both  Y050_999
# 4           0          Country     ZAF  South Africa  both  Y000_999
#
#   age_group_label calendar_quarter quarter_label   indicator indicator_label  \
# 0           15-49         CY2017Q2    2017-06-01  population      Population
# 1           15-64         CY2017Q2    2017-06-01  population      Population
# 2             15+         CY2017Q2    2017-06-01  population      Population
# 3             50+         CY2017Q2    2017-06-01  population      Population
# 4        all ages         CY2017Q2    2017-06-01  population      Population
#
#           mean            se        median          mode         lower  \
# ...

# %%
df['area_name'].unique()
# Out:
# array(['South Africa', 'Western Cape', 'Northern Cape', 'Eastern Cape',
#        'Free State', 'KwaZulu-Natal', 'Mpumalanga', 'Limpopo',
#        'North West', 'Gauteng', 'Cape Town MM', 'West Coast DM',
#        'Cape Winelands DM', 'Overberg DM', 'Garden Route DM',
#        'Central Karoo DM', 'Namakwa DM', 'Pixley ka Seme DM',
#        'ZF Mgcawu DM', 'Frances Baard DM', 'J T Gaetsewe DM',
#        'Buffalo City MM', 'N Mandela Bay MM', 'Sarah Baartman DM',
#        'Amathole DM', 'C Hani DM', 'Joe Gqabi DM', 'O Tambo DM',
#        'A Nzo DM', 'Mangaung MM', 'Xhariep DM', 'Lejweleputswa DM',
#        'T Mofutsanyana DM', 'Fezile Dabi DM', 'eThekwini MM', 'Ugu DM',
#        'uMgungundlovu DM', 'Uthukela DM', 'Umzinyathi DM', 'Amajuba DM',
#        'Zululand DM', 'Umkhanyakude DM', 'King Cetshwayo DM', 'iLembe DM',
#        'Harry Gwala DM', 'G Sibande DM', 'Nkangala DM', 'Ehlanzeni DM',
#        'Mopani DM', 'Vhembe DM', 'Capricorn DM', 'Waterberg DM',
# ...

# %%
#creating new dataframes according to each key indicator for analysis
specific_df1= df[df['indicator_label']== 'PLHIV not on ART']
specific_df2= df[df['indicator_label']== 'Number PLHIV unaware']
specific_df3= df[df['indicator_label']== 'Number PLHIV aware']
specific_df4= df[df['indicator_label']== 'New infections']

# %%
specific_df1['indicator_label'].unique()
# Out:
# array(['PLHIV not on ART'], dtype=object)

# %%
specific_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36828 entries, 792 to 628622
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   area_level        36828 non-null  int64
#  1   area_level_label  36828 non-null  object
#  2   area_id           36828 non-null  object
#  3   area_name         36828 non-null  object
#  4   sex               36828 non-null  object
#  5   age_group         36828 non-null  object
#  6   age_group_label   36828 non-null  object
#  7   calendar_quarter  36828 non-null  object
#  8   quarter_label     36828 non-null  datetime64[ns]
#  9   indicator         36828 non-null  object
#  10  indicator_label   36828 non-null  object
#  11  mean              36828 non-null  float64
#  12  se                36828 non-null  float64
#  13  median            36828 non-null  float64
#  14  mode              36828 non-null  float64
#  15  lower             36828 non-null  float64
# ...

# %%
province=['South Africa', 'Western Cape','Northern Cape', 'Eastern Cape',
       'Free State', 'KwaZulu-Natal', 'Mpumalanga', 'Limpopo',
       'North West', 'Gauteng']

# %%
specific_df1= specific_df1[specific_df1['area_name'].isin(province)].reset_index(drop= True)

# %%
specific_df1['area_name'].unique()
# Out:
# array(['South Africa', 'Western Cape', 'Northern Cape', 'Eastern Cape',
#        'Free State', 'KwaZulu-Natal', 'Mpumalanga', 'Limpopo',
#        'North West', 'Gauteng'], dtype=object)

# %%
specific_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5940 entries, 0 to 5939
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   area_level        5940 non-null   int64
#  1   area_level_label  5940 non-null   object
#  2   area_id           5940 non-null   object
#  3   area_name         5940 non-null   object
#  4   sex               5940 non-null   object
#  5   age_group         5940 non-null   object
#  6   age_group_label   5940 non-null   object
#  7   calendar_quarter  5940 non-null   object
#  8   quarter_label     5940 non-null   datetime64[ns]
#  9   indicator         5940 non-null   object
#  10  indicator_label   5940 non-null   object
#  11  mean              5940 non-null   float64
#  12  se                5940 non-null   float64
#  13  median            5940 non-null   float64
#  14  mode              5940 non-null   float64
#  15  lower             5940 non-null   float64
# ...

# %%
specific_df2= specific_df2[specific_df2['area_name'].isin(province)].reset_index(drop= True)
specific_df3= specific_df3[specific_df3['area_name'].isin(province)].reset_index(drop= True)
specific_df4= specific_df4[specific_df4['area_name'].isin(province)].reset_index(drop= True)

# %%
#creating new dataframes which will include the municipalities
Municipalities= ['Cape Town MM','Buffalo City MM', 'N Mandela Bay MM','Mangaung MM', 'eThekwini MM','Johannesburg MM',
       'Tshwane MM', 'Ekurhuleni MM',]
M1_df=df[df['indicator_label']== 'PLHIV not on ART']
M2_df=df[df['indicator_label']== 'Number PLHIV unaware']
M3_df=df[df['indicator_label']== 'Number PLHIV aware']
M4_df=df[df['indicator_label']== 'New infections']

# %%
M1_df=M1_df[M1_df['area_name'].isin(Municipalities)].reset_index(drop= True)
M2_df=M2_df[M2_df['area_name'].isin(Municipalities)].reset_index(drop= True)
M3_df=M3_df[M3_df['area_name'].isin(Municipalities)].reset_index(drop= True)
M4_df=M4_df[M4_df['area_name'].isin(Municipalities)].reset_index(drop= True)

# %%
M1_df['area_name'].unique()
# Out:
# array(['Cape Town MM', 'Buffalo City MM', 'N Mandela Bay MM',
#        'Mangaung MM', 'eThekwini MM', 'Johannesburg MM', 'Tshwane MM',
#        'Ekurhuleni MM'], dtype=object)

# %%
District= ['West Coast DM',
       'Cape Winelands DM', 'Overberg DM', 'Garden Route DM',
       'Central Karoo DM', 'Namakwa DM', 'Pixley ka Seme DM',
       'ZF Mgcawu DM', 'Frances Baard DM', 'J T Gaetsewe DM','Sarah Baartman DM',
       'Amathole DM', 'C Hani DM', 'Joe Gqabi DM', 'O Tambo DM',
       'A Nzo DM','Xhariep DM', 'Lejweleputswa DM',
       'T Mofutsanyana DM', 'Fezile Dabi DM','Ugu DM',
       'uMgungundlovu DM', 'Uthukela DM', 'Umzinyathi DM', 'Amajuba DM',
       'Zululand DM', 'Umkhanyakude DM', 'King Cetshwayo DM', 'iLembe DM',
       'Harry Gwala DM', 'G Sibande DM', 'Nkangala DM', 'Ehlanzeni DM',
       'Mopani DM', 'Vhembe DM', 'Capricorn DM', 'Waterberg DM',
       'Sekhukhune DM', 'Bojanala Platinum DM', 'Ngaka Modiri Molema DM',
       'Ruth Segomotsi Mompati DM', 'Dr K Kaunda DM','Sedibeng DM', 'West Rand DM']

# %%
#creating new dataframes which will have district municipalities
d1_df= df[df['indicator_label']== 'PLHIV not on ART']
d2_df=df[df['indicator_label']== 'Number PLHIV unaware']
d3_df=df[df['indicator_label']== 'Number PLHIV aware']
d4_df=df[df['indicator_label']== 'New infections']

# %%
d1_df= d1_df[d1_df['area_name'].isin(District)].reset_index(drop=True)
d2_df= d2_df[d2_df['area_name'].isin(District)].reset_index(drop=True)
d3_df= d3_df[d3_df['area_name'].isin(District)].reset_index(drop=True)
d4_df= d4_df[d4_df['area_name'].isin(District)].reset_index(drop=True)

# %%
#exporting the data
specific_df1.to_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV DATA CLEANED\PHLHIV not ART.xlsx")
specific_df2.to_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV DATA CLEANED\Number PLHIV unaware.xlsx")
specific_df3.to_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV DATA CLEANED\Number PLHIV aware.xlsx")
specific_df4.to_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV DATA CLEANED\New infections.xlsx")

# %%
d1_df.to_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV DATA CLEANED\District PHLHIV not ART.xlsx")
d2_df.to_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV DATA CLEANED\District Number PLHIV unaware.xlsx")
d3_df.to_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV DATA CLEANED\District Number PLHIV aware.xlsx")
d4_df.to_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV DATA CLEANED\District New infections.xlsx")

# %%
M1_df.to_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV DATA CLEANED\Municipal PHLHIV not ART.xlsx")
M2_df.to_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV DATA CLEANED\Municipal Number PLHIV unaware.xlsx")
M3_df.to_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV DATA CLEANED\Municipal Number PLHIV aware.xlsx")
M4_df.to_excel(r"C:\Users\sandi\OneDrive\Desktop\HIV DATA CLEANED\Municipal New infections.xlsx")
